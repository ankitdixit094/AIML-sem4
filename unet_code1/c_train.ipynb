# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
def create_dir(path):
    """Create a directory."""
    try:
        if not os.path.exists(path):
            os.makedirs(path)
    except FileExistsError as e:
        pass

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

physical_devices = tf.config.experimental.list_physical_devices("GPU")
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)


def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x

    return tf.numpy_function(f, [y_true, y_pred], tf.float32)


smooth = 1e-15


def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )


def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Activation,
    BatchNormalization,
    Concatenate,
    Conv2D,
    Conv2DTranspose,
    Input,
    MaxPool2D,
)
from tensorflow.keras.models import Model

physical_devices = tf.config.experimental.list_physical_devices("GPU")
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)


def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 16)
    s2, p2 = encoder_block(p1, 32)
    s3, p3 = encoder_block(p2, 64)
    s4, p4 = encoder_block(p3, 128)
    s5, p5 = encoder_block(p4, 256)
    s6, p6 = encoder_block(p5, 512)

    b1 = conv_block(p6, 1024)

    d1 = decoder_block(b1, s6, 512)
    d2 = decoder_block(d1, s5, 256)
    d3 = decoder_block(d2, s4, 128)
    d4 = decoder_block(d3, s3, 64)
    d5 = decoder_block(d4, s2, 32)
    d6 = decoder_block(d5, s1, 16)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d6)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
import os
from glob import glob

import cv2
import numpy as np
import tensorflow as tf
from sklearn.utils import shuffle
from tensorflow.keras.callbacks import (
    CSVLogger,
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau,
    TensorBoard,
)
from tensorflow.keras.metrics import Accuracy, Precision, Recall
from tensorflow.keras.optimizers import Adam

# from a_image_annotation import create_dir
# from metrics import dice_coef, dice_loss, iou
# from model_1 import build_unet

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print(physical_devices)
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

W = 512
H = 512


def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def load_data(path):
    x = sorted(glob(os.path.join(path, "images", "*.jpg")))
    y = sorted(glob(os.path.join(path, "masks", "*.jpg")))
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR + cv2.IMREAD_IGNORE_ORIENTATION)
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = x/255.0
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    save_model = "save_model_1"
    create_dir(save_model)

    """ Hyperparameters """
    batch_size = 15
    lr = 1e-4
    num_epochs = 50

    model_path = os.path.join(save_model, "model.keras")
    csv_path = os.path.join(save_model, "data.csv")

    """ Dataset """
    # dataset_path = os.path.join("data")
    train_path = os.path.join("/content/drive/MyDrive/Colab Notebooks/sem4/3_unet/unet_code1", "data", "train_data", "512x512")
    valid_path = os.path.join("/content/drive/MyDrive/Colab Notebooks/sem4/3_unet/unet_code1", "data", "val_data", "512x512")

    train_x, train_y = load_data(train_path)
    train_x, train_y = shuffling(train_x, train_y)
    valid_x, valid_y = load_data(valid_path)
    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    """ Model """
    model = build_unet((H, W, 3))
    model.summary()
    # metrics = [dice_coef, iou, Recall(), Precision()]
    # metrics = [dice_coef, Recall(), Precision()]load_data
    metrics = [dice_coef, Recall(), Precision(), Accuracy()]
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=False),
    ]

    model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks,
        shuffle=False
    )
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Train: 786 - 786
# Valid: 100 - 100
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 512, 512, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 512, 512, 16)   │            448 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 512, 512, 16)   │             64 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 512, 512, 16)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 512, 512, 16)   │          2,320 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 512, 512, 16)   │             64 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 512, 512, 16)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 256, 256, 16)   │              0 │ activation_1[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 256, 256, 32)   │          4,640 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 256, 256, 32)   │            128 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 256, 256, 32)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 256, 256, 32)   │          9,248 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 256, 256, 32)   │            128 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 256, 256, 32)   │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 128, 128, 32)   │              0 │ activation_3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 128, 128, 64)   │         18,496 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 128, 128, 64)   │            256 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 128, 128, 64)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 128, 128, 64)   │         36,928 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 128, 128, 64)   │            256 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 128, 128, 64)   │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 64, 64, 64)     │              0 │ activation_5[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 64, 64, 128)    │         73,856 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 64, 64, 128)    │            512 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 64, 64, 128)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 64, 64, 128)    │        147,584 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 64, 64, 128)    │            512 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 64, 64, 128)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 32, 32, 128)    │              0 │ activation_7[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 32, 256)    │        295,168 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 32, 32, 256)    │          1,024 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 32, 32, 256)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 32, 256)    │        590,080 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 32, 32, 256)    │          1,024 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 32, 32, 256)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 16, 16, 256)    │              0 │ activation_9[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 512)    │      1,180,160 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 8, 8, 512)      │              0 │ activation_11[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 8, 8, 1024)     │      4,719,616 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 8, 8, 1024)     │          4,096 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 8, 8, 1024)     │      9,438,208 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 8, 8, 1024)     │          4,096 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 512)    │      2,097,664 │ activation_13[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ activation_11[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 16, 16, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 16, 16, 512)    │          2,048 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 16, 16, 512)    │          2,048 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 256)    │        524,544 │ activation_15[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 32, 32, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 32, 32, 256)    │          1,024 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 32, 32, 256)    │        590,080 │ activation_16[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 32, 32, 256)    │          1,024 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 128)    │        131,200 │ activation_17[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 64, 256)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ activation_7[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 64, 64, 128)    │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 64, 64, 128)    │            512 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_18             │ (None, 64, 64, 128)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 64, 64, 128)    │        147,584 │ activation_18[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 64, 64, 128)    │            512 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_19             │ (None, 64, 64, 128)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 128, 128, 64)   │         32,832 │ activation_19[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 128, 128, 128)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 128, 128, 64)   │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 128, 128, 64)   │            256 │ conv2d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_20             │ (None, 128, 128, 64)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 128, 128, 64)   │         36,928 │ activation_20[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 128, 128, 64)   │            256 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_21             │ (None, 128, 128, 64)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 256, 256, 32)   │          8,224 │ activation_21[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 256, 256, 64)   │              0 │ conv2d_transpose_4[0]… │
# │ (Concatenate)             │                        │                │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 256, 256, 32)   │         18,464 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 256, 256, 32)   │            128 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_22             │ (None, 256, 256, 32)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 256, 256, 32)   │          9,248 │ activation_22[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 256, 256, 32)   │            128 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_23             │ (None, 256, 256, 32)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_5        │ (None, 512, 512, 16)   │          2,064 │ activation_23[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 512, 512, 32)   │              0 │ conv2d_transpose_5[0]… │
# │ (Concatenate)             │                        │                │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 512, 512, 16)   │          4,624 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 512, 512, 16)   │             64 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_24             │ (None, 512, 512, 16)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 512, 512, 16)   │          2,320 │ activation_24[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 512, 512, 16)   │             64 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_25             │ (None, 512, 512, 16)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 512, 512, 1)    │             17 │ activation_25[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,134,321 (118.77 MB)
#  Trainable params: 31,122,161 (118.72 MB)
#  Non-trainable params: 12,160 (47.50 KB)
# Epoch 1/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.0000e+00 - dice_coef: 0.0181 - loss: 0.9819 - precision: 0.0294 - recall: 0.3924
# Epoch 1: val_loss improved from inf to 0.99146, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 514s 8s/step - accuracy: 0.0000e+00 - dice_coef: 0.0183 - loss: 0.9817 - precision: 0.0295 - recall: 0.3972 - val_accuracy: 0.0000e+00 - val_dice_coef: 0.0085 - val_loss: 0.9915 - val_precision: 0.0027 - val_recall: 0.0051 - learning_rate: 1.0000e-04
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 1.0703e-05 - dice_coef: 0.0451 - loss: 0.9549 - precision: 0.0604 - recall: 0.9289
# Epoch 2: val_loss improved from 0.99146 to 0.99057, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 38s 694ms/step - accuracy: 1.1196e-05 - dice_coef: 0.0452 - loss: 0.9548 - precision: 0.0607 - recall: 0.9288 - val_accuracy: 0.0000e+00 - val_dice_coef: 0.0094 - val_loss: 0.9906 - val_precision: 0.0056 - val_recall: 0.0101 - learning_rate: 1.0000e-04
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 2.1440e-04 - dice_coef: 0.0577 - loss: 0.9423 - precision: 0.1120 - recall: 0.9207
# Epoch 3: val_loss did not improve from 0.99057
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 33s 623ms/step - accuracy: 2.1586e-04 - dice_coef: 0.0578 - loss: 0.9423 - precision: 0.1123 - recall: 0.9207 - val_accuracy: 0.0000e+00 - val_dice_coef: 0.0094 - val_loss: 0.9906 - val_precision: 0.0028 - val_recall: 0.0023 - learning_rate: 1.0000e-04
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 5.0461e-04 - dice_coef: 0.0649 - loss: 0.9352 - precision: 0.1440 - recall: 0.9223
# Epoch 4: val_loss did not improve from 0.99057
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 33s 625ms/step - accuracy: 5.0525e-04 - dice_coef: 0.0649 - loss: 0.9351 - precision: 0.1442 - recall: 0.9223 - val_accuracy: 0.0000e+00 - val_dice_coef: 0.0085 - val_loss: 0.9915 - val_precision: 0.0023 - val_recall: 0.0011 - learning_rate: 1.0000e-04
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 6.9853e-04 - dice_coef: 0.0706 - loss: 0.9294 - precision: 0.1679 - recall: 0.9231
# Epoch 5: val_loss did not improve from 0.99057
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 40s 614ms/step - accuracy: 6.9863e-04 - dice_coef: 0.0707 - loss: 0.9293 - precision: 0.1681 - recall: 0.9231 - val_accuracy: 0.0000e+00 - val_dice_coef: 0.0077 - val_loss: 0.9924 - val_precision: 0.0015 - val_recall: 1.1693e-04 - learning_rate: 1.0000e-04
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 8.2073e-04 - dice_coef: 0.0768 - loss: 0.9232 - precision: 0.1921 - recall: 0.9318
# Epoch 6: val_loss did not improve from 0.99057
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 34s 630ms/step - accuracy: 8.2096e-04 - dice_coef: 0.0769 - loss: 0.9232 - precision: 0.1923 - recall: 0.9318 - val_accuracy: 0.0000e+00 - val_dice_coef: 0.0074 - val_loss: 0.9926 - val_precision: 0.0093 - val_recall: 1.0794e-04 - learning_rate: 1.0000e-04
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - accuracy: 9.3736e-04 - dice_coef: 0.0839 - loss: 0.9161 - precision: 0.2240 - recall: 0.9439
# Epoch 7: val_loss improved from 0.99057 to 0.98984, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 45s 713ms/step - accuracy: 9.3764e-04 - dice_coef: 0.0840 - loss: 0.9160 - precision: 0.2243 - recall: 0.9439 - val_accuracy: 0.0000e+00 - val_dice_coef: 0.0102 - val_loss: 0.9898 - val_precision: 0.7298 - val_recall: 0.0257 - learning_rate: 1.0000e-04
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.0010 - dice_coef: 0.0911 - loss: 0.9090 - precision: 0.2524 - recall: 0.9490
# Epoch 8: val_loss improved from 0.98984 to 0.96302, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 36s 663ms/step - accuracy: 0.0010 - dice_coef: 0.0912 - loss: 0.9089 - precision: 0.2525 - recall: 0.9491 - val_accuracy: 6.3324e-06 - val_dice_coef: 0.0364 - val_loss: 0.9630 - val_precision: 0.5774 - val_recall: 0.3720 - learning_rate: 1.0000e-04
# Epoch 9/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0011 - dice_coef: 0.0982 - loss: 0.9018 - precision: 0.2757 - recall: 0.9498
# Epoch 9: val_loss improved from 0.96302 to 0.93199, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 43s 717ms/step - accuracy: 0.0011 - dice_coef: 0.0983 - loss: 0.9017 - precision: 0.2757 - recall: 0.9498 - val_accuracy: 4.1988e-04 - val_dice_coef: 0.0672 - val_loss: 0.9320 - val_precision: 0.2778 - val_recall: 0.7903 - learning_rate: 1.0000e-04
# Epoch 10/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.0012 - dice_coef: 0.1048 - loss: 0.8952 - precision: 0.2874 - recall: 0.9451
# Epoch 10: val_loss did not improve from 0.93199
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 34s 629ms/step - accuracy: 0.0012 - dice_coef: 0.1049 - loss: 0.8951 - precision: 0.2876 - recall: 0.9451 - val_accuracy: 1.7593e-04 - val_dice_coef: 0.0552 - val_loss: 0.9443 - val_precision: 0.4244 - val_recall: 0.6277 - learning_rate: 1.0000e-04
# Epoch 11/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.0013 - dice_coef: 0.1127 - loss: 0.8874 - precision: 0.2994 - recall: 0.9473
# Epoch 11: val_loss did not improve from 0.93199
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 33s 611ms/step - accuracy: 0.0013 - dice_coef: 0.1128 - loss: 0.8872 - precision: 0.2998 - recall: 0.9474 - val_accuracy: 3.1582e-04 - val_dice_coef: 0.0535 - val_loss: 0.9462 - val_precision: 0.4496 - val_recall: 0.6204 - learning_rate: 1.0000e-04
# Epoch 12/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - accuracy: 0.0014 - dice_coef: 0.1228 - loss: 0.8772 - precision: 0.3297 - recall: 0.9549
# Epoch 12: val_loss did not improve from 0.93199
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 48s 741ms/step - accuracy: 0.0014 - dice_coef: 0.1229 - loss: 0.8771 - precision: 0.3301 - recall: 0.9549 - val_accuracy: 5.8708e-04 - val_dice_coef: 0.0624 - val_loss: 0.9371 - val_precision: 0.4101 - val_recall: 0.6591 - learning_rate: 1.0000e-04
# Epoch 13/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.0015 - dice_coef: 0.1327 - loss: 0.8673 - precision: 0.3490 - recall: 0.9560
# Epoch 13: val_loss improved from 0.93199 to 0.91664, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 35s 665ms/step - accuracy: 0.0015 - dice_coef: 0.1329 - loss: 0.8672 - precision: 0.3495 - recall: 0.9560 - val_accuracy: 0.0022 - val_dice_coef: 0.0832 - val_loss: 0.9166 - val_precision: 0.1801 - val_recall: 0.9148 - learning_rate: 1.0000e-04
# Epoch 14/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0016 - dice_coef: 0.1430 - loss: 0.8570 - precision: 0.3615 - recall: 0.9562
# Epoch 14: val_loss did not improve from 0.91664
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 34s 627ms/step - accuracy: 0.0016 - dice_coef: 0.1431 - loss: 0.8569 - precision: 0.3620 - recall: 0.9562 - val_accuracy: 0.0029 - val_dice_coef: 0.0735 - val_loss: 0.9264 - val_precision: 0.1033 - val_recall: 0.9535 - learning_rate: 1.0000e-04
# Epoch 15/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.0016 - dice_coef: 0.1535 - loss: 0.8466 - precision: 0.3689 - recall: 0.9545
# Epoch 15: val_loss improved from 0.91664 to 0.91198, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 43s 678ms/step - accuracy: 0.0016 - dice_coef: 0.1537 - loss: 0.8464 - precision: 0.3694 - recall: 0.9545 - val_accuracy: 0.0011 - val_dice_coef: 0.0878 - val_loss: 0.9120 - val_precision: 0.3695 - val_recall: 0.6928 - learning_rate: 1.0000e-04
# Epoch 16/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.0017 - dice_coef: 0.1665 - loss: 0.8335 - precision: 0.4035 - recall: 0.9488
# Epoch 16: val_loss improved from 0.91198 to 0.90951, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 43s 719ms/step - accuracy: 0.0017 - dice_coef: 0.1667 - loss: 0.8334 - precision: 0.4039 - recall: 0.9488 - val_accuracy: 9.8824e-04 - val_dice_coef: 0.0907 - val_loss: 0.9095 - val_precision: 0.3714 - val_recall: 0.6415 - learning_rate: 1.0000e-04
# Epoch 17/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0018 - dice_coef: 0.1807 - loss: 0.8194 - precision: 0.4239 - recall: 0.9503
# Epoch 17: val_loss did not improve from 0.90951
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 36s 628ms/step - accuracy: 0.0018 - dice_coef: 0.1809 - loss: 0.8192 - precision: 0.4243 - recall: 0.9502 - val_accuracy: 2.8217e-04 - val_dice_coef: 0.0701 - val_loss: 0.9298 - val_precision: 0.5427 - val_recall: 0.4139 - learning_rate: 1.0000e-04
# Epoch 18/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - accuracy: 0.0018 - dice_coef: 0.1938 - loss: 0.8063 - precision: 0.4240 - recall: 0.9478
# Epoch 18: val_loss did not improve from 0.90951
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 33s 616ms/step - accuracy: 0.0018 - dice_coef: 0.1940 - loss: 0.8061 - precision: 0.4245 - recall: 0.9477 - val_accuracy: 3.7510e-04 - val_dice_coef: 0.0858 - val_loss: 0.9137 - val_precision: 0.5186 - val_recall: 0.4935 - learning_rate: 1.0000e-04
# Epoch 19/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.0019 - dice_coef: 0.2095 - loss: 0.7905 - precision: 0.4470 - recall: 0.9450
# Epoch 19: val_loss improved from 0.90951 to 0.88021, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 38s 719ms/step - accuracy: 0.0019 - dice_coef: 0.2097 - loss: 0.7903 - precision: 0.4474 - recall: 0.9449 - val_accuracy: 8.4858e-04 - val_dice_coef: 0.1192 - val_loss: 0.8802 - val_precision: 0.4132 - val_recall: 0.6933 - learning_rate: 1.0000e-04
# Epoch 20/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.0019 - dice_coef: 0.2274 - loss: 0.7727 - precision: 0.4868 - recall: 0.9386
# Epoch 20: val_loss improved from 0.88021 to 0.86609, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.0019 - dice_coef: 0.2276 - loss: 0.7725 - precision: 0.4870 - recall: 0.9386 - val_accuracy: 0.0010 - val_dice_coef: 0.1331 - val_loss: 0.8661 - val_precision: 0.3967 - val_recall: 0.7349 - learning_rate: 1.0000e-04
# Epoch 21/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.0020 - dice_coef: 0.2471 - loss: 0.7529 - precision: 0.5169 - recall: 0.9395
# Epoch 21: val_loss did not improve from 0.86609
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 60s 642ms/step - accuracy: 0.0020 - dice_coef: 0.2474 - loss: 0.7527 - precision: 0.5171 - recall: 0.9395 - val_accuracy: 7.1301e-04 - val_dice_coef: 0.1288 - val_loss: 0.8699 - val_precision: 0.4803 - val_recall: 0.6309 - learning_rate: 1.0000e-04
# Epoch 22/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.0021 - dice_coef: 0.2683 - loss: 0.7317 - precision: 0.5434 - recall: 0.9412
# Epoch 22: val_loss did not improve from 0.86609
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 40s 625ms/step - accuracy: 0.0021 - dice_coef: 0.2686 - loss: 0.7315 - precision: 0.5437 - recall: 0.9411 - val_accuracy: 2.4155e-04 - val_dice_coef: 0.0996 - val_loss: 0.8988 - val_precision: 0.5449 - val_recall: 0.4096 - learning_rate: 1.0000e-04
# Epoch 23/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - accuracy: 0.0022 - dice_coef: 0.2899 - loss: 0.7101 - precision: 0.5647 - recall: 0.9403
# Epoch 23: val_loss did not improve from 0.86609
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 41s 621ms/step - accuracy: 0.0022 - dice_coef: 0.2902 - loss: 0.7099 - precision: 0.5650 - recall: 0.9402 - val_accuracy: 3.7994e-05 - val_dice_coef: 0.0564 - val_loss: 0.9429 - val_precision: 0.5982 - val_recall: 0.1798 - learning_rate: 1.0000e-04
# Epoch 24/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0022 - dice_coef: 0.3105 - loss: 0.6895 - precision: 0.5767 - recall: 0.9349
# Epoch 24: val_loss did not improve from 0.86609
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 33s 618ms/step - accuracy: 0.0022 - dice_coef: 0.3108 - loss: 0.6893 - precision: 0.5770 - recall: 0.9348 - val_accuracy: 2.0554e-04 - val_dice_coef: 0.1081 - val_loss: 0.8908 - val_precision: 0.5453 - val_recall: 0.3728 - learning_rate: 1.0000e-04
# Epoch 25/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.0022 - dice_coef: 0.3325 - loss: 0.6675 - precision: 0.5967 - recall: 0.9287
# Epoch 25: val_loss improved from 0.86609 to 0.84863, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 44s 678ms/step - accuracy: 0.0022 - dice_coef: 0.3328 - loss: 0.6673 - precision: 0.5969 - recall: 0.9286 - val_accuracy: 5.9868e-04 - val_dice_coef: 0.1502 - val_loss: 0.8486 - val_precision: 0.4568 - val_recall: 0.5443 - learning_rate: 1.0000e-04
# Epoch 26/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.0023 - dice_coef: 0.3572 - loss: 0.6428 - precision: 0.6165 - recall: 0.9297
# Epoch 26: val_loss improved from 0.84863 to 0.82553, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 41s 682ms/step - accuracy: 0.0023 - dice_coef: 0.3575 - loss: 0.6426 - precision: 0.6168 - recall: 0.9297 - val_accuracy: 8.0879e-04 - val_dice_coef: 0.1728 - val_loss: 0.8255 - val_precision: 0.4584 - val_recall: 0.6091 - learning_rate: 1.0000e-04
# Epoch 27/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.0024 - dice_coef: 0.3821 - loss: 0.6179 - precision: 0.6365 - recall: 0.9281
# Epoch 27: val_loss improved from 0.82553 to 0.80824, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 40s 738ms/step - accuracy: 0.0024 - dice_coef: 0.3824 - loss: 0.6176 - precision: 0.6368 - recall: 0.9280 - val_accuracy: 0.0015 - val_dice_coef: 0.1900 - val_loss: 0.8082 - val_precision: 0.3787 - val_recall: 0.7067 - learning_rate: 1.0000e-04
# Epoch 28/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.0024 - dice_coef: 0.4043 - loss: 0.5957 - precision: 0.6373 - recall: 0.9282
# Epoch 28: val_loss improved from 0.80824 to 0.78808, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 40s 718ms/step - accuracy: 0.0024 - dice_coef: 0.4046 - loss: 0.5954 - precision: 0.6378 - recall: 0.9280 - val_accuracy: 0.0016 - val_dice_coef: 0.2109 - val_loss: 0.7881 - val_precision: 0.3954 - val_recall: 0.7147 - learning_rate: 1.0000e-04
# Epoch 29/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.0025 - dice_coef: 0.4268 - loss: 0.5732 - precision: 0.6464 - recall: 0.9244
# Epoch 29: val_loss improved from 0.78808 to 0.77943, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 43s 757ms/step - accuracy: 0.0025 - dice_coef: 0.4271 - loss: 0.5729 - precision: 0.6470 - recall: 0.9242 - val_accuracy: 0.0013 - val_dice_coef: 0.2191 - val_loss: 0.7794 - val_precision: 0.4689 - val_recall: 0.6540 - learning_rate: 1.0000e-04
# Epoch 30/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.0025 - dice_coef: 0.4511 - loss: 0.5489 - precision: 0.6657 - recall: 0.9200
# Epoch 30: val_loss improved from 0.77943 to 0.76419, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 37s 683ms/step - accuracy: 0.0025 - dice_coef: 0.4514 - loss: 0.5487 - precision: 0.6662 - recall: 0.9198 - val_accuracy: 0.0015 - val_dice_coef: 0.2344 - val_loss: 0.7642 - val_precision: 0.4327 - val_recall: 0.6810 - learning_rate: 1.0000e-04
# Epoch 31/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.0025 - dice_coef: 0.4723 - loss: 0.5277 - precision: 0.6748 - recall: 0.9139
# Epoch 31: val_loss did not improve from 0.76419
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 34s 627ms/step - accuracy: 0.0025 - dice_coef: 0.4726 - loss: 0.5275 - precision: 0.6752 - recall: 0.9137 - val_accuracy: 0.0011 - val_dice_coef: 0.2294 - val_loss: 0.7684 - val_precision: 0.5152 - val_recall: 0.5660 - learning_rate: 1.0000e-04
# Epoch 32/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.0025 - dice_coef: 0.4955 - loss: 0.5046 - precision: 0.7016 - recall: 0.9039
# Epoch 32: val_loss improved from 0.76419 to 0.73533, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 45s 707ms/step - accuracy: 0.0025 - dice_coef: 0.4958 - loss: 0.5043 - precision: 0.7018 - recall: 0.9039 - val_accuracy: 0.0014 - val_dice_coef: 0.2633 - val_loss: 0.7353 - val_precision: 0.4841 - val_recall: 0.6534 - learning_rate: 1.0000e-04
# Epoch 33/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.0025 - dice_coef: 0.5230 - loss: 0.4770 - precision: 0.7259 - recall: 0.9076
# Epoch 33: val_loss did not improve from 0.73533
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 37s 626ms/step - accuracy: 0.0025 - dice_coef: 0.5233 - loss: 0.4767 - precision: 0.7261 - recall: 0.9077 - val_accuracy: 9.0282e-04 - val_dice_coef: 0.2492 - val_loss: 0.7488 - val_precision: 0.5747 - val_recall: 0.5174 - learning_rate: 1.0000e-04
# Epoch 34/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0026 - dice_coef: 0.5511 - loss: 0.4489 - precision: 0.7486 - recall: 0.9151
# Epoch 34: val_loss did not improve from 0.73533
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 41s 627ms/step - accuracy: 0.0026 - dice_coef: 0.5514 - loss: 0.4486 - precision: 0.7488 - recall: 0.9151 - val_accuracy: 9.3712e-04 - val_dice_coef: 0.2605 - val_loss: 0.7375 - val_precision: 0.5513 - val_recall: 0.5300 - learning_rate: 1.0000e-04
# Epoch 35/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.0026 - dice_coef: 0.5754 - loss: 0.4246 - precision: 0.7646 - recall: 0.9178
# Epoch 35: val_loss did not improve from 0.73533
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 40s 612ms/step - accuracy: 0.0026 - dice_coef: 0.5757 - loss: 0.4244 - precision: 0.7648 - recall: 0.9177 - val_accuracy: 7.8594e-04 - val_dice_coef: 0.2523 - val_loss: 0.7450 - val_precision: 0.5769 - val_recall: 0.4797 - learning_rate: 1.0000e-04
# Epoch 36/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0026 - dice_coef: 0.5929 - loss: 0.4071 - precision: 0.7691 - recall: 0.9124
# Epoch 36: val_loss did not improve from 0.73533
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 42s 628ms/step - accuracy: 0.0026 - dice_coef: 0.5932 - loss: 0.4069 - precision: 0.7693 - recall: 0.9123 - val_accuracy: 6.4335e-04 - val_dice_coef: 0.2483 - val_loss: 0.7496 - val_precision: 0.6033 - val_recall: 0.4343 - learning_rate: 1.0000e-04
# Epoch 37/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - accuracy: 0.0026 - dice_coef: 0.6105 - loss: 0.3895 - precision: 0.7781 - recall: 0.9071
# Epoch 37: val_loss improved from 0.73533 to 0.70033, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 47s 739ms/step - accuracy: 0.0026 - dice_coef: 0.6108 - loss: 0.3893 - precision: 0.7784 - recall: 0.9071 - val_accuracy: 9.9110e-04 - val_dice_coef: 0.2974 - val_loss: 0.7003 - val_precision: 0.5667 - val_recall: 0.5396 - learning_rate: 1.0000e-04
# Epoch 38/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.0027 - dice_coef: 0.6342 - loss: 0.3659 - precision: 0.7888 - recall: 0.9191
# Epoch 38: val_loss did not improve from 0.70033
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 35s 626ms/step - accuracy: 0.0027 - dice_coef: 0.6344 - loss: 0.3657 - precision: 0.7891 - recall: 0.9189 - val_accuracy: 8.3534e-04 - val_dice_coef: 0.2968 - val_loss: 0.7012 - val_precision: 0.5857 - val_recall: 0.4976 - learning_rate: 1.0000e-04
# Epoch 39/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.0027 - dice_coef: 0.6532 - loss: 0.3469 - precision: 0.8009 - recall: 0.9193
# Epoch 39: val_loss did not improve from 0.70033
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 34s 629ms/step - accuracy: 0.0027 - dice_coef: 0.6534 - loss: 0.3467 - precision: 0.8011 - recall: 0.9191 - val_accuracy: 8.2279e-04 - val_dice_coef: 0.2974 - val_loss: 0.7006 - val_precision: 0.5749 - val_recall: 0.4913 - learning_rate: 1.0000e-04
# Epoch 40/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.0027 - dice_coef: 0.6611 - loss: 0.3389 - precision: 0.8029 - recall: 0.9034
# Epoch 40: val_loss did not improve from 0.70033
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 41s 629ms/step - accuracy: 0.0027 - dice_coef: 0.6613 - loss: 0.3387 - precision: 0.8030 - recall: 0.9034 - val_accuracy: 6.8222e-04 - val_dice_coef: 0.2928 - val_loss: 0.7048 - val_precision: 0.6136 - val_recall: 0.4520 - learning_rate: 1.0000e-04
# Epoch 41/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.0027 - dice_coef: 0.6712 - loss: 0.3288 - precision: 0.8004 - recall: 0.8988
# Epoch 41: val_loss improved from 0.70033 to 0.69098, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 47s 743ms/step - accuracy: 0.0027 - dice_coef: 0.6715 - loss: 0.3286 - precision: 0.8005 - recall: 0.8988 - val_accuracy: 7.3891e-04 - val_dice_coef: 0.3073 - val_loss: 0.6910 - val_precision: 0.6014 - val_recall: 0.4650 - learning_rate: 1.0000e-04
# Epoch 42/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.0027 - dice_coef: 0.6902 - loss: 0.3098 - precision: 0.8139 - recall: 0.9047
# Epoch 42: val_loss did not improve from 0.69098
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 35s 627ms/step - accuracy: 0.0027 - dice_coef: 0.6905 - loss: 0.3096 - precision: 0.8141 - recall: 0.9047 - val_accuracy: 6.4129e-04 - val_dice_coef: 0.2899 - val_loss: 0.7082 - val_precision: 0.6263 - val_recall: 0.4078 - learning_rate: 1.0000e-04
# Epoch 43/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0027 - dice_coef: 0.7090 - loss: 0.2911 - precision: 0.8270 - recall: 0.9124
# Epoch 43: val_loss did not improve from 0.69098
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 41s 627ms/step - accuracy: 0.0027 - dice_coef: 0.7092 - loss: 0.2909 - precision: 0.8272 - recall: 0.9124 - val_accuracy: 4.1847e-04 - val_dice_coef: 0.2579 - val_loss: 0.7400 - val_precision: 0.6912 - val_recall: 0.3324 - learning_rate: 1.0000e-04
# Epoch 44/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.0028 - dice_coef: 0.7236 - loss: 0.2764 - precision: 0.8385 - recall: 0.9128
# Epoch 44: val_loss improved from 0.69098 to 0.66318, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 36s 683ms/step - accuracy: 0.0028 - dice_coef: 0.7238 - loss: 0.2763 - precision: 0.8386 - recall: 0.9128 - val_accuracy: 8.4545e-04 - val_dice_coef: 0.3342 - val_loss: 0.6632 - val_precision: 0.5892 - val_recall: 0.4796 - learning_rate: 1.0000e-04
# Epoch 45/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0028 - dice_coef: 0.7291 - loss: 0.2709 - precision: 0.8399 - recall: 0.9024
# Epoch 45: val_loss did not improve from 0.66318
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 38s 627ms/step - accuracy: 0.0028 - dice_coef: 0.7293 - loss: 0.2707 - precision: 0.8401 - recall: 0.9025 - val_accuracy: 6.6147e-04 - val_dice_coef: 0.3060 - val_loss: 0.6920 - val_precision: 0.6448 - val_recall: 0.3933 - learning_rate: 1.0000e-04
# Epoch 46/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.0028 - dice_coef: 0.7412 - loss: 0.2589 - precision: 0.8405 - recall: 0.9080
# Epoch 46: val_loss did not improve from 0.66318
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 41s 627ms/step - accuracy: 0.0028 - dice_coef: 0.7413 - loss: 0.2587 - precision: 0.8407 - recall: 0.9080 - val_accuracy: 4.2751e-04 - val_dice_coef: 0.2606 - val_loss: 0.7374 - val_precision: 0.6942 - val_recall: 0.3023 - learning_rate: 1.0000e-04
# Epoch 47/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.0028 - dice_coef: 0.7530 - loss: 0.2471 - precision: 0.8482 - recall: 0.9107
# Epoch 47: val_loss did not improve from 0.66318
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 40s 611ms/step - accuracy: 0.0028 - dice_coef: 0.7531 - loss: 0.2470 - precision: 0.8482 - recall: 0.9107 - val_accuracy: 4.6680e-04 - val_dice_coef: 0.2901 - val_loss: 0.7068 - val_precision: 0.6888 - val_recall: 0.3406 - learning_rate: 1.0000e-04
# Epoch 48/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - accuracy: 0.0028 - dice_coef: 0.7636 - loss: 0.2364 - precision: 0.8619 - recall: 0.9047
# Epoch 48: val_loss improved from 0.66318 to 0.62331, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 37s 694ms/step - accuracy: 0.0028 - dice_coef: 0.7638 - loss: 0.2363 - precision: 0.8618 - recall: 0.9048 - val_accuracy: 9.7763e-04 - val_dice_coef: 0.3735 - val_loss: 0.6233 - val_precision: 0.5996 - val_recall: 0.4999 - learning_rate: 1.0000e-04
# Epoch 49/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.0029 - dice_coef: 0.7710 - loss: 0.2290 - precision: 0.8636 - recall: 0.9040
# Epoch 49: val_loss did not improve from 0.62331
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 37s 615ms/step - accuracy: 0.0029 - dice_coef: 0.7712 - loss: 0.2289 - precision: 0.8636 - recall: 0.9040 - val_accuracy: 9.4990e-04 - val_dice_coef: 0.3626 - val_loss: 0.6345 - val_precision: 0.6046 - val_recall: 0.4639 - learning_rate: 1.0000e-04
# Epoch 50/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - accuracy: 0.0029 - dice_coef: 0.7738 - loss: 0.2262 - precision: 0.8554 - recall: 0.9022
# Epoch 50: val_loss improved from 0.62331 to 0.58999, saving model to save_model_1/model.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 47s 733ms/step - accuracy: 0.0029 - dice_coef: 0.7740 - loss: 0.2261 - precision: 0.8555 - recall: 0.9022 - val_accuracy: 0.0012 - val_dice_coef: 0.4064 - val_loss: 0.5900 - val_precision: 0.5760 - val_recall: 0.5446 - learning_rate: 1.0000e-04

# %% [markdown]
# # d_eval_1

# %%
# %pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)

# %%
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

from glob import glob

import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    jaccard_score,
    precision_score,
    recall_score,
)
from tensorflow.keras.utils import CustomObjectScope
from tqdm import tqdm

physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

H = 512
W = 512

""" Creating a directory """
def create_dir(path):
    """Create a directory."""
    try:
        if not os.path.exists(path):
            os.makedirs(path)
    except FileExistsError as e:
        pass

def save_results(image, mask, y_pred, save_image_path):
    ## i - m - y
    line = np.ones((H, 10, 3)) * 128

    """ Mask """
    mask = np.expand_dims(mask, axis=-1)    ## (512, 512, 1)
    mask = np.concatenate([mask, mask, mask], axis=-1)  ## (512, 512, 3)

    """ Predicted Mask """
    y_pred = np.expand_dims(y_pred, axis=-1)    ## (512, 512, 1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)  ## (512, 512, 3)
    y_pred = y_pred * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)


def load_data(path):
    x = sorted(glob(os.path.join(path, "images", "*.jpg")))
    y = sorted(glob(os.path.join(path, "masks", "*.jpg")))
    return x, y

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    # create_dir("results_1")
    save_image_path = os.path.join("/content/drive/MyDrive/Colab Notebooks/sem4/3_unet/unet_code1", "results", "test_data", '512x512')
    create_dir(save_image_path)

    """ Loading model """
    with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_loss': dice_loss}):
        model = tf.keras.models.load_model("save_model_1/model.keras")

    """ Load the dataset """
    test_path = os.path.join("/content/drive/MyDrive/Colab Notebooks/sem4/3_unet/unet_code1", "data", "test_data", "512x512")
    # test_path = os.path.join("data", "test_data", "512x512")

    test_x, test_y = load_data(test_path)
    print(f"Test: {len(test_x)} - {len(test_y)}")

    """ Evaluation and Prediction """
    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Extract the name """
        # save_image_path = os.path.join("result_final", "test_data", '512x512', f"{name}")
        name = x.split("/")[-1]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR + cv2.IMREAD_IGNORE_ORIENTATION)
        x = image/255.0
        x = np.expand_dims(x, axis=0)

        """ Reading the mask """
        mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        y = mask/255.0
        y = y > 0.5
        y = y.astype(np.int32)

        """ Prediction """
        y_pred = model.predict(x)[0]
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred > 0.5
        y_pred = y_pred.astype(np.int32)

        """ Saving the prediction """
        save_image_path = os.path.join("/content/drive/MyDrive/Colab Notebooks/sem4/3_unet/unet_code1", "results", "test_data", '512x512', f'{name}')
        save_results(image, mask, y_pred, save_image_path)

        """ Flatten the array """
        y = y.flatten()
        y_pred = y_pred.flatten()

        """ Calculating the metrics values """
        acc_value = accuracy_score(y, y_pred)
        f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary", zero_division=1)
        jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary", zero_division=1)
        recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary", zero_division=1)
        precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary", zero_division=1)
        SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

    """ Metrics values """
    score = [s[1:]for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"Accuracy: {score[0]:0.5f}")
    print(f"F1: {score[1]:0.5f}")
    print(f"Jaccard: {score[2]:0.5f}")
    print(f"Recall: {score[3]:0.5f}")
    print(f"Precision: {score[4]:0.5f}")

    df = pd.DataFrame(SCORE, columns=["Image", "Accuracy", "F1", "Jaccard", "Recall", "Precision"])
    df.to_csv("save_model_1/d_evel_test_score.csv")
# Out:
# Test: 94 - 94
#   0%|          | 0/94 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#   1%|          | 1/94 [00:02<04:15,  2.75s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#   2%|▏         | 2/94 [00:04<03:01,  1.97s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   3%|▎         | 3/94 [00:05<02:30,  1.66s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   4%|▍         | 4/94 [00:06<02:23,  1.59s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#   5%|▌         | 5/94 [00:08<02:25,  1.64s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#   6%|▋         | 6/94 [00:10<02:27,  1.67s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#   7%|▋         | 7/94 [00:11<02:16,  1.57s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   9%|▊         | 8/94 [00:13<02:08,  1.49s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  10%|▉         | 9/94 [00:14<01:59,  1.41s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  11%|█         | 10/94 [00:15<01:55,  1.38s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  12%|█▏        | 11/94 [00:17<01:55,  1.39s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  13%|█▎        | 12/94 [00:18<01:56,  1.43s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#  14%|█▍        | 13/94 [00:19<01:50,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#  15%|█▍        | 14/94 [00:21<01:57,  1.47s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#  16%|█▌        | 15/94 [00:23<02:00,  1.53s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  17%|█▋        | 16/94 [00:24<01:55,  1.48s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  18%|█▊        | 17/94 [00:25<01:49,  1.42s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  19%|█▉        | 18/94 [00:27<01:45,  1.39s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  20%|██        | 19/94 [00:28<01:43,  1.39s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  21%|██▏       | 20/94 [00:29<01:41,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#  22%|██▏       | 21/94 [00:31<01:42,  1.41s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  23%|██▎       | 22/94 [00:32<01:40,  1.40s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#  24%|██▍       | 23/94 [00:34<01:46,  1.50s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#  26%|██▌       | 24/94 [00:35<01:45,  1.51s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  27%|██▋       | 25/94 [00:37<01:44,  1.51s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  28%|██▊       | 26/94 [00:38<01:38,  1.45s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#  29%|██▊       | 27/94 [00:40<01:33,  1.39s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  30%|██▉       | 28/94 [00:41<01:29,  1.36s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#  31%|███       | 29/94 [00:42<01:29,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  32%|███▏      | 30/94 [00:44<01:29,  1.39s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  33%|███▎      | 31/94 [00:45<01:26,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  34%|███▍      | 32/94 [00:47<01:30,  1.45s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  35%|███▌      | 33/94 [00:48<01:33,  1.53s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#  36%|███▌      | 34/94 [00:50<01:29,  1.49s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  37%|███▋      | 35/94 [00:51<01:24,  1.44s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  38%|███▊      | 36/94 [00:52<01:21,  1.40s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  39%|███▉      | 37/94 [00:54<01:18,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  40%|████      | 38/94 [00:55<01:17,  1.38s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  41%|████▏     | 39/94 [00:57<01:16,  1.39s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  43%|████▎     | 40/94 [00:58<01:13,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  44%|████▎     | 41/94 [00:59<01:15,  1.43s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#  45%|████▍     | 42/94 [01:01<01:18,  1.51s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#  46%|████▌     | 43/94 [01:02<01:14,  1.46s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  47%|████▋     | 44/94 [01:04<01:11,  1.43s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  48%|████▊     | 45/94 [01:05<01:08,  1.40s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  49%|████▉     | 46/94 [01:06<01:05,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  50%|█████     | 47/94 [01:08<01:05,  1.38s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  51%|█████     | 48/94 [01:09<01:04,  1.39s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  52%|█████▏    | 49/94 [01:11<01:01,  1.38s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  53%|█████▎    | 50/94 [01:12<00:58,  1.32s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#  54%|█████▍    | 51/94 [01:14<01:01,  1.44s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#  55%|█████▌    | 52/94 [01:15<01:00,  1.45s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#  56%|█████▋    | 53/94 [01:16<00:56,  1.38s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  57%|█████▋    | 54/94 [01:18<00:54,  1.36s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  59%|█████▊    | 55/94 [01:19<00:55,  1.43s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#  60%|█████▉    | 56/94 [01:21<00:56,  1.48s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  61%|██████    | 57/94 [01:22<00:53,  1.46s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  62%|██████▏   | 58/94 [01:24<00:52,  1.46s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  63%|██████▎   | 59/94 [01:25<00:50,  1.44s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#  64%|██████▍   | 60/94 [01:27<00:50,  1.48s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#  65%|██████▍   | 61/94 [01:28<00:47,  1.44s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  66%|██████▌   | 62/94 [01:29<00:44,  1.40s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  67%|██████▋   | 63/94 [01:31<00:43,  1.40s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  68%|██████▊   | 64/94 [01:32<00:42,  1.41s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  69%|██████▉   | 65/94 [01:33<00:40,  1.41s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  70%|███████   | 66/94 [01:35<00:39,  1.39s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  71%|███████▏  | 67/94 [01:36<00:35,  1.32s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  72%|███████▏  | 68/94 [01:37<00:34,  1.33s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  73%|███████▎  | 69/94 [01:39<00:34,  1.38s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#  74%|███████▍  | 70/94 [01:40<00:35,  1.46s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#  76%|███████▌  | 71/94 [01:42<00:33,  1.46s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  77%|███████▋  | 72/94 [01:43<00:31,  1.45s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  78%|███████▊  | 73/94 [01:45<00:29,  1.38s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  79%|███████▊  | 74/94 [01:46<00:28,  1.41s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  80%|███████▉  | 75/94 [01:47<00:26,  1.41s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  81%|████████  | 76/94 [01:49<00:24,  1.35s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  82%|████████▏ | 77/94 [01:50<00:22,  1.35s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#  83%|████████▎ | 78/94 [01:52<00:23,  1.44s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#  84%|████████▍ | 79/94 [01:53<00:22,  1.47s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  85%|████████▌ | 80/94 [01:54<00:19,  1.42s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  86%|████████▌ | 81/94 [01:56<00:18,  1.42s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#  87%|████████▋ | 82/94 [01:57<00:16,  1.41s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  88%|████████▊ | 83/94 [01:59<00:15,  1.44s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  89%|████████▉ | 84/94 [02:00<00:14,  1.44s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  90%|█████████ | 85/94 [02:02<00:12,  1.42s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  91%|█████████▏| 86/94 [02:03<00:10,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#  93%|█████████▎| 87/94 [02:05<00:10,  1.46s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#  94%|█████████▎| 88/94 [02:06<00:09,  1.54s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  95%|█████████▍| 89/94 [02:08<00:07,  1.46s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  96%|█████████▌| 90/94 [02:09<00:05,  1.40s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  97%|█████████▋| 91/94 [02:10<00:04,  1.37s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  98%|█████████▊| 92/94 [02:11<00:02,  1.36s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  99%|█████████▉| 93/94 [02:13<00:01,  1.38s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 100%|██████████| 94/94 [02:14<00:00,  1.43s/it]
# Accuracy: 0.99337
# F1: 0.42225
# Jaccard: 0.28446
# Recall: 0.49226
# Precision: 0.43454
